# %% [markdown]
# <a href="https://colab.research.google.com/github/karlinnn/ML-Practice/blob/main/EDA_Univariate_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("/content/master_students.csv")

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  ...  python sql  ml certifications  Python  SQL  \
# 0   Sci&Tech     No  ...       0   0   0              1       0    0
# 1   Sci&Tech    Yes  ...       0   1   1              3       1    0
# 2  Comm&Mgmt     No  ...       1   1   1              3       1    1
# 3   Sci&Tech     No  ...       0   0   0              1       1    1
# 4  Comm&Mgmt     No  ...       1   1   1              2       0    1
#
#    Machine Learning  Excel  Cloud  expected_salary
# 0                 0      0      1     13800.147869
# ...

# %% [markdown]
# # **1. Categorical Data**

# %% [markdown]
# ### `i) Countplot`

# %%
sns.countplot(df["workex"])
df['hsc_s'].value_counts()
#df['Zone'].value_counts().plot(kind='bar')
# Out:
# hsc_s
# Commerce    113
# Science      91
# Arts         11
# Name: count, dtype: int64

# %% [markdown]
# ### ii)Pie Chart

# %%
df["degree_t"].value_counts().plot(kind='pie',autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # **2. Numerical Data**

# %% [markdown]
# ### i) Histogram

# %%
import matplotlib.pyplot as plt
plt.hist(df["degree_p"])
# Out:
# (array([10., 25., 26., 58., 35., 34., 16.,  7.,  3.,  1.]),
#  array([50. , 54.1, 58.2, 62.3, 66.4, 70.5, 74.6, 78.7, 82.8, 86.9, 91. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### ii) Distplot

# %%
sns.distplot(df["degree_p"])
# Out:
# /tmp/ipython-input-650738242.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["degree_p"])
# <Axes: xlabel='degree_p', ylabel='Density'>

# %% [markdown]
# ### iii) Boxplot

# %%
sns.boxplot(df["hsc_p"])
# Out:
# <Axes: ylabel='hsc_p'>
